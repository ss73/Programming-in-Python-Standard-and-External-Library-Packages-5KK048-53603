# %% [markdown]
# Lab 3 - Part 4a: Working with strings
# ========

# %%
print("Hello world! It's nice today")
# Out:
# Hello world! It's nice today

# %% [markdown]
# You can also have single quotes (note the backslash for escaping).

# %%
print('Hello world! It\'s nice today')
# Out:
# Hello world! It's nice today

# %% [markdown]
# You can also have triple quotes for strings with newline

# %%
print("""
Hello world!
It's nice today
""")
# Out:
# Hello world!
# It's nice today

# %% [markdown]
# Or use the newline character `\n`

# %%
print("Hello world!\nIt's nice today")
# Out:
# Hello world!
# It's nice today

# %% [markdown]
# F-strings make it easier to construct strings with variable content. (Note the f in front of the ")

# %%
name = "Birthday kid"
age = 30

print(f"Hello, {name}. You are now {age} years.")
# Out:
# Hello, Birthday kid. You are now 30 years.

# %% [markdown]
# II. Concatenating strings
# --------------------------
#
# You can use `+` to concatenate strings.
# ❓💬❓ 1) By using the built-in function`type`, you find out the type of variable.  Using the built-in function, what does it return as the type for the variabe `str_2`? What does it return as the type for the variable`next_year_age`?
#
# ❓💬❓ 2) Use the variable `next_year_age` to instead print the string "Next year you will become 31".

# %%
str_1 = "Next year you will become"
str_2 = "a bit older"
next_year_age = 31

# Change here:
print(str_1 + " " + str(next_year_age))
# Out:
# Next year you will become 31

# %% [markdown]
# ❓💬❓ 3)  There are some (but not that many) [built-in functions](https://docs.python.org/3/library/functions.html) in Python.
# ***Which three built-in functions have you used in the code above? One of them returns `None`. Which one? How many parameters did you send to the functions? What were the types of these parameters?**

# %%
print('Answer 1, Type for str2:', type(str_2))
print('Answer 2, Type for next_year_age:', type(next_year_age))
print('Answer 3a, Used built-in functions: type(), print(), str()')
print('Answer 3b, Return value for print() ***', print(), '*** (note side effect of actually printing an empty line)')
# Out:
# Answer 1, Type for str2: <class 'str'>
# Answer 2, Type for next_year_age: <class 'int'>
# Answer 3a, Used built-in functions: type(), print(), str()
#
# Answer 3b, Return value for print() *** None *** (note side effect of actually printing an empty line)

# %% [markdown]
# III. More built-in functions
# -----------------------------------------------------
#
# With the built-in function `len()`, you can find out the length of things, for instance the number of letters in a string
#
# ❓💬❓ 4) What type does `len()` return?
#
# The built-in function `sorted()` does not only sort lists, but also strings.
#
# ❓💬❓5) What type does sorted() return?
#
# You can also apply the built-in function `set()` to turn all the letters in the string into a set of unique letters.
#
# 💻💻YOUR CODE HERE: **6) Finish the function below, so that is uses the two built-in functions sorted() and set() so that it returns a sorted list (unique occurrecess) with all the letters in the string that is given as a parameter to the function. So that if `hello` is given as input, the output should be  `['e', 'h', 'l', 'o']`**. I.e., 'l' should only occur once.
#
# Much of the lab will consist of updating the `get_sorted_list_from_str` function

# %%
print('Answer 4:', type(len('abc')))
print('Answer 5:', type(sorted('abc')))
# Out:
# Answer 4: <class 'int'>
# Answer 5: <class 'list'>

# %%
# Answer 6
def get_sorted_list_from_str(input_str):
    #Add code here
    return sorted(set(input_str)) 

sorted_list = get_sorted_list_from_str("hello")
print(sorted_list) # Should be ['e', 'h', 'l', 'o']
# Out:
# ['e', 'h', 'l', 'o']

# %% [markdown]
# IV. String methods (without arguments)
# -------------------------------------
#
# While there are few general built-in Python functions that can be applied to lists, there are many *methods* that are specifically associated with i.e., the built-in types. For instance, methods that are associated with strings. A complete list of methods associated with strings can be found here:
# https://docs.python.org/3/library/stdtypes.html#string-methods
#
# ❓💬❓ 7) Is there a colour difference in the editor you are using (or in Kaggle), depending on if you are writing the name of a function or of a method? **How does the syntax for a method differ from that of a function?**
#
#
# We will use a few of the string methods here. We start with the method `str.upper()`.

# %%
print("Answer 7: First using a string function, then a string method...")
print("  - '" + str.strip(' leading and trailing white spaces\n \t') + "'")
print("  -", ' '.join(['list','of', 'words', 'joined', 'by', 'spaces']))
print("No difference in coloring that I can see (editing in Kaggle)")
print("\nSyntax for a method differs from a function:\n  - function: class.function(<args>)\n  - method: instance.method(<args>)")
# Out:
# Answer 7: First using a string function, then a string method...
#   - 'leading and trailing white spaces'
#   - list of words joined by spaces
# No difference in coloring that I can see (editing in Kaggle)
#
# Syntax for a method differs from a function:
#   - function: class.function(<args>)
#   - method: instance.method(<args>)

# %%
original_hello = "Hello World!"
upper_hello = original_hello.upper()
print("Original string:", original_hello)
print("Changed string:", upper_hello)
# Out:
# Original string: Hello World!
# Changed string: HELLO WORLD!

# %% [markdown]
# ❓💬❓What does `.upper()` return?
#
# Note that the syntax of a **method** is different from that of a **built-in function**. For a method, you:
#  1. first write the variable (on whose content you want to apply the method)
#  2. then a `.`,
#  3. and then the name of the method.
#
# Note that the content of the variable `original_hello` is not changed, but that the method returns an altered string, which we save in another variable that we call `lowered_hello`.
#
# (Note that print can also take several arguments, so that is a way to print several strings, instead of concatenating them or using f-string.)

# %% [markdown]
# 💻💻YOUR CODE HERE:
# 8) **Find an appropriate method from [the string documentation](https://docs.python.org/3/library/stdtypes.html#string-methods), and change you function `get_sorted_list_from_str()` above, so that it first makes the input parameter string into lower-case, before sorting it.**

# %%
def get_sorted_list_from_str(input):
    return sorted(set(input.lower()))

# %%
# Test that it works:
sorted_list = get_sorted_list_from_str("Hello")
print(sorted_list) # Should be ['e', 'h', 'l', 'o']
# Out:
# ['e', 'h', 'l', 'o']

# %% [markdown]
# V. String methods with arguments
# ---------------------------------
#
# Perhaps you noted that the method `upper()` was written with an empty paranthesis. That means that we didn't send any arguments to the method. (This statement might be argued about, if you dig very deep into Python, but for now, it's a very reasonable simplification.) Often, however, you also send information to methods in the form of arguments. For instance, the `replace()` method takes two arguments:
#  1. The substring to find in the string for which you call the method,
#  2. and the string to replace it with.

# %%
replaced_hello = original_hello.replace("!", "?")
print(replaced_hello)
# Out:
# Hello World?

# %% [markdown]
# You can also replace a sequence of letters.
# `""` means an empty string.

# %%
replaced_hello_keeping_only_world = replaced_hello.replace("Hello ", "")
print(replaced_hello_keeping_only_world)
# Out:
# World?

# %% [markdown]
# If you want, you can do the two replacements above on one line

# %%
replaced_string = original_hello.replace("!", "?").replace("Hello ", "")
print(replaced_string)
# Out:
# World?

# %% [markdown]
# 💻💻YOUR CODE HERE: **9) Use the `replace` method to change code in the `get_sorted_list_from_str`, so that 'é' is replaced with 'e', before the string is changed to a list.**

# %%
def get_sorted_list_from_str(input):
    return sorted(set(input.lower().replace('é','e')))

# %%
# Test that is works
sorted_list = get_sorted_list_from_str("Beyoncé")
print(sorted_list) # Should be ['b', 'c', 'e', 'n', 'o', 'y']
# Out:
# ['b', 'c', 'e', 'n', 'o', 'y']

# %% [markdown]
# ❓💬❓ 10) Try the string string methods `count()` and `find()`. What do they take as arguments? What do they return?

# %%
print("Answer 10a: count l's in 'hello world':", "hello world".count('l'))
print("Answer 10b: find start index of 'world' in 'hello world':", "hello world".find('world'))
print("Both takes a match string and optionally start and end indices as arguments, returns an int denoting the number of occurrencies and start index respectively")
# Out:
# Answer 10a: count l's in 'hello world': 3
# Answer 10b: find start index of 'world' in 'hello world': 6
# Both takes a match string and optionally start and end indices as arguments, returns an int denoting the number of occurrencies and start index respectively

# %% [markdown]
# VI. String methods that return a boolean
# -----------------------------------------
# There are a number of string methods that return a boolean. For instance `endswith()`.
#
# ❓💬❓ 11) What does the `strip()` method below do?

# %%
print("Hello world".endswith("world"))
print("Hello world ".endswith("world"))
print("Hello world ".strip().endswith("world"))
print("Answer 11: The strip() method removes leading and trailing white space (e.g. space, tab, newline)")
# Out:
# True
# False
# True
# Answer 11: The strip() method removes leading and trailing white space (e.g. space, tab, newline)

# %% [markdown]
# 💻💻YOUR CODE HERE: **11) Use the `isdigit()` method to change the code in the `get_sorted_list_from_str`, so that your function returns `None` if all characthers in the string given as a parameter are digits. Print out a message where you tell the user that strings with only digits are not allowed**

# %%
def get_sorted_list_from_str(input):
    if input.isdigit():
        return None
    return sorted(set(input.lower().replace('é','e')))

assert get_sorted_list_from_str('1234567890987654321') is None
assert get_sorted_list_from_str('CBA') == ['a', 'b', 'c']

# %% [markdown]
# VII. The Python keyword `in` with strings (and a bit of recap regarding Python keywords)
# ----------------------------------------------------------------------------------------
#
# **Python keywords** are reserved words in Python that cannot be used for anything else.
#
# You are not allowed to use the keywords as variable names.
# 11) How does your editor (e.g. Kaggle) colour code Python keywords?
#
# A full list of Python keywords can be found here:
# https://docs.python.org/3/reference/lexical_analysis.html#keywords
#
# One example of a keyword that can be applied to strings is the keyword `in`.

# %%
def check_for_exclamation_mark(input_str):
    if '!' in input_str:
        print(input_str, "contains exclamation mark")
    else:
        print(input_str, "does not contain exclamation mark")
        
check_for_exclamation_mark("Hello word!")
check_for_exclamation_mark("Hello word")
# Out:
# Hello word! contains exclamation mark
# Hello word does not contain exclamation mark

# %% [markdown]
# 💻💻YOUR CODE HERE: **12) Use the keyword `in` to change the code in the `get_sorted_list_from_str`, so that your function returns `None` if the string contains '!'. Print out a message to the user about that strings with ! are not allowed.**

# %%
def get_sorted_list_from_str(input):
    if '!' in input:
        print('Interjections are not allowed here!')
        return None
    if input.isdigit():
        return None
    return sorted(set(input.lower().replace('é','e')))

assert get_sorted_list_from_str("Fore!") is None
# Out:
# Interjections are not allowed here!

# %% [markdown]
# Some examples of where the Python keywords **if** **and**, **or** and **not** are used with strings:

# %%
check_for_letters_str = "Hello World!"

if 'e' in check_for_letters_str and 'o' in check_for_letters_str:
    print("1. " + check_for_letters_str + " contains both 'e' and 'o'.")
          
if 'e' in check_for_letters_str and 'a' in check_for_letters_str:
    print("2. " + check_for_letters_str + " contains both 'e' and 'a'.")

if 'e' in check_for_letters_str or 'a' in check_for_letters_str:
    print("3. " + check_for_letters_str + " contains 'e' or 'a'.")
    
if 'e' in check_for_letters_str and not 'a' in check_for_letters_str:
    print("4. " + check_for_letters_str + " contains 'e' and does not contain 'a'.")
# Out:
# 1. Hello World! contains both 'e' and 'o'.
# 3. Hello World! contains 'e' or 'a'.
# 4. Hello World! contains 'e' and does not contain 'a'.

# %% [markdown]
# 💻💻YOUR CODE HERE: 13) Change the string stored in `check_for_letters_str`, so that only the third condition becomes true. I.e. so that only ".. contains 'e' or 'a'." is printed. (If you don't manage to find a solution, don't worry, this will not be on the quizz :) )

# %%
check_for_letters_str = "Hallu Wurld!"

if 'e' in check_for_letters_str and 'o' in check_for_letters_str:
    print("1. " + check_for_letters_str + " contains both 'e' and 'o'.")
          
if 'e' in check_for_letters_str and 'a' in check_for_letters_str:
    print("2. " + check_for_letters_str + " contains both 'e' and 'a'.")

if 'e' in check_for_letters_str or 'a' in check_for_letters_str:
    print("3. " + check_for_letters_str + " contains 'e' or 'a'.")
    
if 'e' in check_for_letters_str and not 'a' in check_for_letters_str:
    print("4. " + check_for_letters_str + " contains 'e' and does not contain 'a'.")
# Out:
# 3. Hallu Wurld! contains 'e' or 'a'.

# %% [markdown]
# An empty string, means a string with not content at all, i.e. `""`. White space is counted as content.
#
# 💻💻YOUR CODE HERE: 14) **Do the same if/else-tests for the string 'b', as is done for 'a'.**

# %%
def print_empty_str(s, name):
    if s:
        print("The string '"+name+"' has content")
    else:
        print("'"+name+"' is an empty string")
print_empty_str("", 'a')
print_empty_str(" ", 'b')
# Out:
# 'a' is an empty string
# The string 'b' has content

# %%
a = ""
if a:
    print("The string 'a' has content")
else:
    print("'a' is an empty string")
    
b = " "
# Out:
# 'a' is an empty string

# %% [markdown]
# VIII. Indexing strings
# ------------------------
# It is possible to index a string as follows, to retrieve the character at that position: (Note that you start counting at zero.)

# %%
print(original_hello[0])
print(original_hello[1])
print(original_hello[2])
print(original_hello[3])
print(original_hello[4])
print(original_hello[5])
# Out:
# H
# e
# l
# l
# o

# %% [markdown]
# It is also possible to slice strings.
# You start with the position from the index you want to keep, and then give the first index of the part of the string that you *don't* want to include in the slice.
#
# You can also create a slice from the start, or towards the end, by leaving out the first or the last string index respectively.
#
# You can also use negative numbers

# %%
alphabet_str = "abcdefghijklm"

# To get 'bcd', you start with the index for 'b', i.e. 1, and end with the index after 'd', i.e. 4 (remember start by 0)
print(alphabet_str[1:4])

# From the start
print(alphabet_str[:3])

# Towards the end
print(alphabet_str[5:])

# You can also use negative numbers
print(alphabet_str[-3:])
# Out:
# bcd
# abc
# fghijklm
# klm

# %% [markdown]
# 💻💻YOUR CODE HERE: 15) Print a string with the content "bcdeijklm" by slicing and concatenating `alphabet_st`

# %%
alphabet_str = "abcdefghijklm"
print(alphabet_str[1:5]+alphabet_str[-5:])
# Out:
# bcdeijklm

# %% [markdown]
# 💻💻YOUR CODE HERE: **16) Change the code in the `get_sorted_list_from_str` function, so that it only uses the first 50 letters in the input string when creating the sorted list.**

# %%
def get_sorted_list_from_str(input):
    if len(input) > 50:
        input = input[0:50]
    return sorted(set(input.lower().replace('é','e')))

assert get_sorted_list_from_str("JIHGFEDCBaJIHGFEDCBaJIHGFEDCBaJIHGFEDCBaJIHGFEDCBa9876543210") == ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
# Test that is works
test_50 = "1111111111111111111111111111111111111111111111111122222222222222222222222222222222222222222222222222"
sorted_list = get_sorted_list_from_str(test_50)
print(sorted_list) # Should be ['1']
# Out:
# ['1']

# %% [markdown]
# IV. Mutable and immutable data types
# -------------------------------------
# It might look like strings are a lot like lists. They are. But there is a very important difference:
# Lists are mutable, i.e. it is possible to change their content as follows:
#
# ```
# my_list = [1, 2, 3]
# my_list[0] = 4
# ```
#
# Strings, on the other hand, are immutable, so you cannot change their content. You cant to the assignement with and index as is okay for a list.
#
# So if you want to change the values a lot, it is easier to work with lists. Then, when you have finished changing the content, you can change your list to a string. Note that it is easy to change a list of strings to a string by using the string method `join()´

# %%
my_list = ["It's", "a", "nice", "day"]
my_list[2] = "fine"

print(my_list)
joined = "-".join(my_list)
print(joined)
# Out:
# ["It's", 'a', 'fine', 'day']
# It's-a-fine-day

# %% [markdown]
# 💻💻YOUR CODE HERE:
# **17) Change the code above, so that the final print-out instead is 'It's a fine day'. (I.e., with space instead of hyphen as delimiter.)**
#
# **18) What type of instance is the method `join` applied to? What type does then input parameter to the method have? What type does the method return?**
#
# **19) Try to send a list containing strings to join. What error message do you get?**
#
# **20) There is a also a method that could be said to do the reverse, i.e. splitting up the string to a list. Use `split` to transform 'joined' back to the list format.**
#
# **21) Update the `get_sorted_list_from_str` so that it no longer returns a list, but a string with all the elements in the list. I.e., it should no longer return in the style `['e', 'h', 'l', 'o']`, but `"ehlo"`**
#
# **22) Update the `get_sorted_list_from_str` so that before returning the string, you remove any white space in the beginning or end of the string.**
#
# **23) Run `get_sorted_list_from_str()` with the string "What does allée mean? An allée is a place you can walk among trees. It is an alley in a formal garden or park, bordered by trees or bushes." as the input parameter. What does the method return? How long is the resulting string.**

# %%
print("Answer 17:", " ".join(["It's", "a", "fine", "day"]))
print("Answer 18: a) str, b) iterable, c) str")

try:
    str.join(["It's", "a", "fine", "day"])
except Exception as e:
    print("Answer 19: Error message: >>>", e)

print("Answer 20:", "It's a fine day".split())

def get_sorted_list_from_str(input):
    if len(input) > 50:
        input = input[0:50]
    return ''.join(sorted(set(input.lower().strip().replace('é','e')))).strip()

print("Answer 21:", get_sorted_list_from_str('Hello  '))
print("Answer 22: call strip() on input")
long_str = 'What does allée mean? An allée is a place you can walk among trees. It is an alley in a formal garden or park, bordered by trees or bushes.'
print("Answer 23a:", get_sorted_list_from_str(long_str))
print("Answer 23b: Length is ***", len(get_sorted_list_from_str(long_str)), "*** characters")
# Out:
# Answer 17: It's a fine day
# Answer 18: a) str, b) iterable, c) str
# Answer 19: Error message: >>> descriptor 'join' requires a 'str' object but received a 'list'
# Answer 20: ["It's", 'a', 'fine', 'day']
# Answer 21: ehlo
# Answer 22: call strip() on input
# Answer 23a: ?acdehilmnopstuwy
# Answer 23b: Length is *** 17 *** characters

# %%
# Test that is works
sorted_list = get_sorted_list_from_str("hello")
print(sorted_list) # Should be "ehlo"

# After removing white space:
sorted_list = get_sorted_list_from_str("hello world")
print(sorted_list) # Should be "dehlorw"
# Out:
# ehlo
# dehlorw

# %%
quizz_str = "What does allée mean? An allée is a place you can walk among trees. It is an alley in a formal garden or park, bordered by trees or bushes."
quizz_str_res = get_sorted_list_from_str(quizz_str)
print(quizz_str_res)
print(len(quizz_str_res))
# Out:
# ?acdehilmnopstuwy
# 17

# %% [markdown]
# Extra
# ------
# Whenever it says "# Should be ...." in the code. It is an example of a test case. A better way of doing this, to actually get automated test of that your code works, is to use the `assert` keyword. Rewrite the code, so that it is automatically asserted that your function returns what it should.
#
# Add some error to you function on purpose, to see what happens when the assert is not true.
