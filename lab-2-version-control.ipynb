# %% [markdown]
# Lab 2. Version control
# ===============================
#
# The main point of this assignment is to try version control.
#
# This assignment will also form the examination of the version control part of the course. Upon passing this assignment, you will have completed the version control part of the course.
#
# There is much to learn about version control, and by completing this assignment, you will only have made yourself acquainted with the most basic concepts of it.
#
# In addition to the main aim of version control, you will also practice some Kaggle, the [Markdown syntax](https://daringfireball.net/projects/markdown/basics), as well as get a bit used to the notion of Python libraries.
#
# Remember that when editing you Kaggle notebook, the changes are **not** automatically saved. You need to press "Save version" in the top-right corner.

# %% [markdown]
# ### Task a:
# Copy this notebook by clicking the button 'Edit & Copy' in the top-right corner, so that you have your own version to work with. Save this version by clicking the button 'Save Version'.

# %% [markdown]
# Part I: Kaggle
# ---------------

# %%
from datetime import datetime # Import datetime from the datetime module in the Python Standard Library
from datetime import timedelta # Import timedelta from the datetime module

current_time = datetime.now() # Get current date and time
print("Current date and time: " + str(current_time)) # Print current data and time. The datetime needs to be explicitly type converted into a string

print("In ten days it will be the date and time: " + str(current_time + timedelta(days=10)))
# Out:
# Current date and time: 2024-09-10 22:50:48.701758
# In ten days it will be the date and time: 2024-09-20 22:50:48.701758

# %% [markdown]
# ### Task b
#
# Run the code, and try to understand what it does.

# %% [markdown]
# ### Task c
# Change the code, so that it outputs the date and and time **ten** days from now instead of seven days from now. (And also change the describing text in the message to reflect that change.)
#
# Run the code, make sure it works, and save it by pressing "Save version" in the top-right corner.

# %% [markdown]
# ### Task d
# In the upper right corner in the Kaggle interface, you can see the current version of your code. What version do you have now? Take a look at previous version(s). (Click on the version number to see previous versions.)
#
# Make a **diff** to the previous version, to see what you changed. (Click on the version number, then on the three dots to the right of the version, and then choose ``Compare version``.)

# %% [markdown]
# Part II: Exploring GitHub
# ---------------------------
#
# ### Task e
# Go to the GitHub repository of [CDHU](https://github.com/CDHUppsala), and select one repository with Python code that has more than 5 commits.
#
# What does the code in the repository implement? Does the README give a good description of its function?
#
# >__Chosen repo__: word-rain.<br>The code implements a new take on the classic word cloud.
# The README file gives a good overview of the functionality as well as instructions on how to use
# it for creating your own word rains
#
#
# ### Task f
# Click on the clock, which is positioned just left to the number of commits, to see the history of the repository. What seems to have been changed between the commits?
#
# >__Changes__: The last commit (16b44d6...) contains an update to the README, specifically in the
# _Contributors and funding_ section. The Department of history of science and ideas is now mentioned (including a link to their web site).
#
# ### Task g
# In the Python files you can see what libraries are used. Typically, it is shown right at the top in each Python document. What libraries are used?
#
# >__Imports__: A large number of libraries are used in ``generate_wordrain.py`` which is the source code
# where the bulk of the work is performed, specifically the following:<br><br>
# _sklearn, os, glob, gensim, numpy, matplotlib, mpl_toolkits, scipy, unicodedata, math, string, hashlib,
# bidi.algorithm, json, typing, types, struct, io, collections, re, itertools, time, sys_<br><br>
# (Note: multiple sub libraries, e.g. in sklearn are used, but only the main library is listed for brevity)

# %% [markdown]
# Part III: Using GitHub
# -----------------------

# %% [markdown]
# NOTE: Instructions for GitHub are given here, but any other platform that uses Git and provides a graphic diff is fine to use. In the lecture about this lab, [Codeberg](https://codeberg.org) is given as an example. (For Codeberg, the built-in editor seems to be a bit difficult to use though, so it might be better to edit the markdown file on your own computer and upload it.)

# %% [markdown]
# ### Task h
#  Create an account on [GitHub](https://github.com) (if you don't already have one)
#
# ### Task i
# Create a new private repository with a readme-file and choose one of the licenses.
#
# ### Task j
# Create a new file in your private repository. Give the file the .md file suffix, indicating that it is a markdown file, and edit it in the editor on GitHub.
#
# Answer the following questions, using the suitable markdown syntax, e.g., add headings, subheadings, numbered lists, HTML-link and code blocks.
#
# (i) Give a URL where the module `datetime` in the Python Standard Library is documented.
#
# (ii) What does 'Explicit Type Conversion' mean?
#
# (iii) What date and time will it be in ten days, according to the output of your modified program.
#
# ### Task k
# Commit the .md-file
#
# ### Task l
# Open your markdown file again to edit it more. Augment the text to also include the following:
# (i) Describe some functionality in the `datetime` module that you find useful.
# (ii) Add a practical example of how explicit type conversion is used in Python (for instance copy-paste from the code above)
# (iii) For the libraries you listed in **Task g**, indicate which belong to the Standard Python Library and which are external libraries.
#
# ### Task m
# Commit the file with the additions.
#
# ### Task n
# Click on your markdown file in the Github interface. In the upper right corner, there is a clock/history button where you see all of your commits.
# Click on the the latest commit, to see its diff to the commit-version before that.
# Choose to see the diff compared to the previous commit in "split view"
# Take a screen-shot of this diff.
#
# ### Task o
# Give the screen-shot of the diff a filename containing your name and hand it in to show that you have completed the assignment. (There is an assignment in Studium, called "Version control", and there is also a link to this assignment in the "Lab 2: Version control" module in Studium.)

# %% [markdown]
# Part IV: If you have more time
# -------------------------------
# Clone the git repository that you created to your own computer. Add a python file to the repository, add it, commit it and push to the repository.
